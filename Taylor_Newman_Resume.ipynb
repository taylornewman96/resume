# %%
from matplotlib import pyplot as plt 
from matplotlib import rc

# %matplotlib inline
# Out:
# C:\Users\Taylor Newman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Taylor Newman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\Taylor Newman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
#name and header variables
#include short small comment about how this resume was created with python
name = "TAYLOR NEWMAN"
summary = "Passionate and dedicated computer science professional with experience in\nmachine learning, data analytics, software development, research, and\ngame design."

# %%
#Experience Variables 
expHeader = "Experience"

#Position One
expOneName = "Graduate Teaching Assistant"
expOneCompany = "University of North Carolina at Charlotte"
expOneLocation = "Charlotte, NC"
expOneTimeFrame = "2022"
expOneDescription = "-Assisting in grading of graduate level student work\n-Assisting students with questions regarding the course\n-Addressing group work challenges\n-Investigating academic integrity violations\n-Average of 20 hours per week in addition to a full time course load"

#Position Two
expTwoName = "Undergraduate Teaching Assistant"
expTwoCompany = "University of North Carolina at Charlotte"
expTwoLocation = "Charlotte, NC"
expTwoTimeFrame = "2021"
expTwoDescription = "-Assisted Professor with grading student work and helping students\n with questions about the course\n-Worked through challenges students encountered in group work\n-Average of 20 hours per week in addition to a full time course load"
 
#Position Three
expThreeName = "Research Assistant"
expThreeCompany = "University of North Carolina at Charlotte"
expThreeLocation = "Charlotte, NC"
expThreeTimeFrame = "Summer 2021"
expThreeDescription = "-Assisted in creating a VR related educational experience under\n supervision of a faculty member that led to a published paper\n-Self-guided schedule required time management"

# %%
#Education variables
educationHeader = "Education"

#First Degree
collegeOne = "Campbell University"
collegeOneDegree = "B.B.A Business Administration"
collegeOneGradDate = "Graduation Date: August 2019"

#Second Degree
collegeTwo = "University of North Carolina at Charlotte"
collegeTwoDegree = "B.S. Computer Science"
collegeTwoGPA = "GPA: 3.7"
collegeTwoGradDate = "Graduation Date: December 2021"

#Third Degree
collegeTwoSecondDegree = "M.S. Computer Science"
collegeTwoSecondGPA = "GPA: 3.8"
collegeTwoSecondGradDate = "Expected Graduation Date: August 2022"

# %%
#include a few relevant courses here 
#Modify based on position
relevantCourseTitle = "Relevant Coursework"
relevantCourseUndergrad = "Undergraduate Work: "
relevantCourseUndergradDesc = "Software Engineering, Undergrad Research, Linear Algebra"
relevantCourseGrad = "Graduate Work: "
relevantCourseGradDesc = "Applied Machine Learning, Visual Analytics,\nBig Data Analytics, Data Structures and Algorithms"

# %%
#Personal Information section 
piHeader = "Personal"
location = "Charlotte, NC"
email = "taylorfaye96@gmail.com"
linkedIn = "linkedin.com/in/taylor-newman"

# %%
#Skills section 
skillsHeader = "Technical Skills"
skillsContent = "Pandas\nsklearn\nNumpy\nGit\nData Preprocessing & Manipulation\nJupyter Notebook & Google Colab\nDocker\nRegex"

# %%
#languages 
languagesTitle = "Languages"
languages = "Python\nJava\nC#\nC++\nHTML\n"

# %%
#Projects section 
#Plavana, Revenge, Trapped, NLP project, This resume source code 
#github repo link 
gitSubHeader = 'GitHub'
github = "github.com/taylornewman96"
paperTitle = "Research Publication"
paperLink = "Link to Paper"
myWorkTitle = "List of Work"
listOfWork = "Plavana VR research project\nRevenge Video Game\nTrapped Video Game\nDetecting Hate Speech Using NLP"
#might be beneficial to create a mock up website with some of my work to showcase my skills

# %%
#disclaimer about resume
disclaimer = "*In addition to the other works listed, this\nresume has also been coded and was generated\nin python. The source code can be found on my\ngithub."

# %%
#set parameters for font
plt.rcParams['font.family'] = 'Georgia'

#plt.rcParams['mathtext.fontset'] = 'stixsans'

#set size to size of average piece of paper
fig , ax = plt.subplots(figsize = (8.5,11))

#turn off axis plot
plt.axis('off')

#set background color
ax.set_facecolor('white')

#set the side lines on the paper
#main sidebar
plt.axvline(x=0.99, color='#0C0FBD', alpha=1, linewidth=300)
#personal info line
plt.axhline(y=0.979, xmin=0.7, xmax=0.99, color='#00027f', linewidth=25)
#technical skills line
plt.axhline(y=0.76, xmin=0.7, xmax=0.99, color='#00027f', linewidth=25)
#languages line
plt.axhline(y=0.57, xmin=0.7, xmax=0.99, color='#00027f', linewidth=25)
#projects line
plt.axhline(y=0.45, xmin=0.7, xmax=0.99, color='#00027f', linewidth=25)

#set header 
plt.annotate(name, (0.01,0.96), weight = 'bold', fontsize = 20)


#set summary 
plt.annotate(summary, (0.01, 0.90), fontsize = 8.5)


#Experience Section Header
plt.annotate(expHeader, (0.01,0.87), weight = 'bold', fontsize = 14)

# set work experience - 1st listing 
plt.annotate(expOneName,(0.01,0.84), style = 'oblique', weight = 'bold', fontsize = 11)

plt.annotate(expOneCompany, (0.01,0.82), style = 'italic', fontsize = 10)

plt.annotate(expOneLocation, (0.01, 0.8), style = 'italic', fontsize = 10)

plt.annotate(expOneTimeFrame, (0.6,0.8), style = 'italic', fontsize = 10)

plt.annotate(expOneDescription, (0.01, 0.705), fontsize = 9.5)


# set work experience - 2nd listing 
plt.annotate(expTwoName,(0.01,0.675), style = 'oblique',weight = 'bold', fontsize = 11)

plt.annotate(expOneCompany, (0.01,0.655), style = 'italic', fontsize = 10)

plt.annotate(expOneLocation, (0.01, 0.635), style = 'italic', fontsize = 10)

plt.annotate(expTwoTimeFrame, (0.6,0.635), style = 'italic', fontsize = 10)

plt.annotate(expTwoDescription, (0.01, 0.56), fontsize = 9.5)


# set work experience - 3rd listing 
plt.annotate(expThreeName,(0.01,0.53), style = 'oblique',weight = 'bold', fontsize = 11)

plt.annotate(expOneCompany, (0.01,0.51), style = 'italic', fontsize = 10)

plt.annotate(expOneLocation, (0.01, 0.49), style = 'italic', fontsize = 10)

plt.annotate(expThreeTimeFrame, (0.53,0.49), style = 'italic', fontsize = 10)

plt.annotate(expThreeDescription, (0.01, 0.43), fontsize = 9.5)



# set Education section 
plt.annotate(educationHeader, (0.01,0.39), weight = 'bold', fontsize = 14)

#current college info and grad section header
plt.annotate(collegeTwo, (0.01, 0.365), style = 'oblique', weight = 'bold', fontsize = 10)

#most recent degree
plt.annotate(collegeTwoSecondDegree, (0.01, 0.345), fontsize = 9)
plt.annotate(collegeTwoSecondGradDate,(0.01,0.325), fontsize = 8.5)
plt.annotate(collegeTwoSecondGPA, (0.01, 0.305), style = 'italic', fontsize = 8.5)


#BS computer Science 
plt.annotate(collegeTwoDegree, (0.01, 0.28), fontsize = 9)
plt.annotate(collegeTwoGradDate, (0.01, 0.26), fontsize = 8.5)
plt.annotate(collegeTwoGPA, (0.01, 0.24),style = 'italic', fontsize = 8.5)

#Business Degree from CU
plt.annotate(collegeOne, (0.01, 0.205), style = 'oblique', weight = 'bold', fontsize = 10)
plt.annotate(collegeOneDegree, (0.01, 0.185), fontsize = 9)
plt.annotate(collegeOneGradDate, (0.01, 0.165), fontsize = 8.5)

#Related Coursework 
plt.annotate(relevantCourseTitle, (0.01, 0.125), weight = 'bold', fontsize = 14)
plt.annotate(relevantCourseUndergrad + relevantCourseUndergradDesc, (0.01,0.105), fontsize = 8.5)
plt.annotate(relevantCourseGrad + relevantCourseGradDesc, (0.01,0.07), fontsize = 8.5)



#code for side bar
#Personal Info
plt.annotate(piHeader, (0.685,0.965), style = 'oblique', weight = 'bold', fontsize = 13, color = '#ffffff')
plt.annotate('Phone', (0.685,0.93), weight = 'bold', color = '#ffffff', fontsize = 9)
plt.annotate('(252)-943-1747', (0.685,0.91), color = '#ffffff', fontsize = 8)
# plt.annotate('Location', (0.02, 0.87), weight = 'bold', color = '#ffffff')
# plt.annotate(location, (0.02,0.85), color = '#ffffff')
plt.annotate('Email', (0.685,0.88), weight = 'bold', color = '#ffffff',fontsize = 9)
plt.annotate(email, (0.685, 0.86), color = '#ffffff', fontsize = 8)
plt.annotate('LinkedIn', (0.685, 0.83), weight = 'bold', color = '#ffffff', fontsize = 9)
a = plt.annotate(linkedIn, (0.685, 0.81), color = '#ffffff', fontsize = 8)
a.set_url("https://www.linkedin.com/in/taylor-newman/")

#Technical Skills 
plt.annotate(skillsHeader, (0.685, 0.75), style = 'oblique', weight = 'bold', fontsize = 13, color = '#ffffff')
plt.annotate(skillsContent, (0.685, 0.60), fontsize = 8, color = '#ffffff')


#languages
plt.annotate(languagesTitle, (0.685, 0.56), style = 'oblique', weight = 'bold', fontsize = 13, color = '#ffffff')
plt.annotate(languages, (0.685, 0.46), fontsize = 8, color = '#ffffff')

#projects 
plt.annotate('Projects', (0.685, 0.44), style = 'oblique', weight = 'bold', fontsize = 13, color = '#ffffff')
plt.annotate(gitSubHeader, (0.685,0.40), weight = 'bold', color = '#ffffff', fontsize = 9)
c = plt.annotate(github, (0.685, 0.38), color = '#ffffff', fontsize = 8)
c.set_url("https://github.com/taylornewman96")
#research paper
plt.annotate(paperTitle, (0.685, 0.35), color = '#ffffff', weight = 'bold', fontsize = 9)
b = plt.annotate(paperLink, (0.685, 0.33), color = '#ffffff', weight = 'bold', style ='italic', fontsize = 8)
b.set_url("https://dl.acm.org/doi/fullHtml/10.1145/3450337.3483474")
plt.annotate(myWorkTitle, (0.685, 0.30), color = '#ffffff', weight = 'bold', fontsize = 9)
plt.annotate(listOfWork, (0.685, 0.24), color = '#ffffff', fontsize = 8)

plt.annotate(disclaimer, (0.685,0.03), color = '#ffffff', fontsize = 7)
#save file
plt.savefig('TaylorNewmanResume.pdf', bbox_inches = 'tight', pad_inches = 0.2)
